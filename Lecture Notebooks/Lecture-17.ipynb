# %% [markdown]
# ## Hierarchial Data
#
# We can think of this data as a *tree*

# %% [markdown]
# ### JavaScript Object Notation (JSON)
#
# - One wat to represent hierarchical data. In Python, JSON is represented as **dict**.
# - There are built-in functions like `pd.json_normalize` to flatten JSON to tabular data.

# %% [markdown]
# ### eXtensible Markup Language (XML)
# - Fields are represented by named **tags**
# - Each tag has an open `<tag>` and a close `</tag>`
# - Children are represented by nested tags.
# - Repeated fields are represented by repeated tags.
# - XML documents must begin with the decleratipn `<?xml version="1.0" encoding="UTF-8"?>`
# - XML documents must have a `<root>` tag

# %% [markdown]
# ### JSON vs. XML
# - JSON has largely won over XML.
# - You can occasionally still find hierarchical data as XML, but it usually is JSON.
# - XML is still relevant in data science for one reason: it is a generaliztion of HTML, the lanuage used to specify webpages.
